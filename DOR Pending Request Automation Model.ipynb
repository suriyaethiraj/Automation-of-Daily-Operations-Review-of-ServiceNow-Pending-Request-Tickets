# %%
#Importing Pandas from thr library
import pandas as pd

# Read the Excel file
df = pd.read_excel("Sample Request Dataset.xlsx", engine='openpyxl')

#Create a new column called "Date"
df['Date'] = pd.to_datetime(df['Created']).dt.date

# Create a new column "Age", and calculate the value in days count (Today - Created)
df['Age'] = (pd.Timestamp.now() - pd.to_datetime(df['Date'])).dt.days

# Filter the DataFrame
df = df[df['Age'] > 0]

#append the filter in df1
df1 = df[df['Item'].str.contains('Generic Request Details', na=False)]

# Filter out rows where 'on Hold Reason' column contains 'Schedule Date'
df2 = df1[~df1['on Hold Reason'].str.contains('Schedule Date', na=False)]

# Create a pivot table using the "assignment_group" column
pivot_table = pd.pivot_table(df2, values='Number', index='Assignment group', columns='Age', aggfunc='count')

# Fill NaN values with zeros
pivot_table = pivot_table.fillna(0)

# Format the values as integers (no decimals)
pivot_table = pivot_table.astype(int)

# Append the grand total row to the pivot table
pivot_table_styled = pd.concat([pivot_table])

# Add the total column to the pivot table
pivot_table_styled['Total'] = pivot_table_styled.sum(axis=1)

# Add the total row to the pivot table
pivot_table_styled.loc['Total'] = pivot_table_styled.sum()

# Highlight integer values in red
def highlight_integers(val):
    if isinstance(val, int):
        return 'color: red'
    else:
        return ''

# Apply the style to the pivot table
pivot_table_styled = pivot_table_styled.style.applymap(highlight_integers)

# Set the style for the first four columns (0, 1, 2, 3) to black color
pivot_table_styled = pivot_table_styled.set_properties(subset=pivot_table_styled.columns[:3], color="black")

# Set the style for the "Total" column to black color
pivot_table_styled = pivot_table_styled.set_properties(subset=['Total'], color="black")

# Assign the styled pivot table to DOR_Pending_Incident
DOR_Pending_Incidents = pivot_table_styled

# Renaming the Index Name
DOR_Pending_Incidents.index.name = "Infrastructure Teams"

# Renaming the Column Name
DOR_Pending_Incidents.columns.name = "Pending Request Age"

# Display the styled pivot table
DOR_Pending_Incidents
# Out:
# <ipython-input-81-e454641f09fe>:48: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   pivot_table_styled = pivot_table_styled.style.applymap(highlight_integers)
# <style type="text/css">
# #T_182a7_row0_col0, #T_182a7_row0_col1, #T_182a7_row0_col2, #T_182a7_row0_col14, #T_182a7_row1_col0, #T_182a7_row1_col1, #T_182a7_row1_col2, #T_182a7_row1_col14, #T_182a7_row2_col0, #T_182a7_row2_col1, #T_182a7_row2_col2, #T_182a7_row2_col14, #T_182a7_row3_col0, #T_182a7_row3_col1, #T_182a7_row3_col2, #T_182a7_row3_col14, #T_182a7_row4_col0, #T_182a7_row4_col1, #T_182a7_row4_col2, #T_182a7_row4_col14, #T_182a7_row5_col0, #T_182a7_row5_col1, #T_182a7_row5_col2, #T_182a7_row5_col14, #T_182a7_row6_col0, #T_182a7_row6_col1, #T_182a7_row6_col2, #T_182a7_row6_col14, #T_182a7_row7_col0, #T_182a7_row7_col1, #T_182a7_row7_col2, #T_182a7_row7_col14, #T_182a7_row8_col0, #T_182a7_row8_col1, #T_182a7_row8_col2, #T_182a7_row8_col14, #T_182a7_row9_col0, #T_182a7_row9_col1, #T_182a7_row9_col2, #T_182a7_row9_col14, #T_182a7_row10_col0, #T_182a7_row10_col1, #T_182a7_row10_col2, #T_182a7_row10_col14, #T_182a7_row11_col0, #T_182a7_row11_col1, #T_182a7_row11_col2, #T_182a7_row11_col14, #T_182a7_row12_col0, #T_182a7_row12_col1, #T_182a7_row12_col2, #T_182a7_row12_col14 {
#   color: red;
#   color: black;
# }
# #T_182a7_row0_col3, #T_182a7_row0_col4, #T_182a7_row0_col5, #T_182a7_row0_col6, #T_182a7_row0_col7, #T_182a7_row0_col8, #T_182a7_row0_col9, #T_182a7_row0_col10, #T_182a7_row0_col11, #T_182a7_row0_col12, #T_182a7_row0_col13, #T_182a7_row1_col3, #T_182a7_row1_col4, #T_182a7_row1_col5, #T_182a7_row1_col6, #T_182a7_row1_col7, #T_182a7_row1_col8, #T_182a7_row1_col9, #T_182a7_row1_col10, #T_182a7_row1_col11, #T_182a7_row1_col12, #T_182a7_row1_col13, #T_182a7_row2_col3, #T_182a7_row2_col4, #T_182a7_row2_col5, #T_182a7_row2_col6, #T_182a7_row2_col7, #T_182a7_row2_col8, #T_182a7_row2_col9, #T_182a7_row2_col10, #T_182a7_row2_col11, #T_182a7_row2_col12, #T_182a7_row2_col13, #T_182a7_row3_col3, #T_182a7_row3_col4, #T_182a7_row3_col5, #T_182a7_row3_col6, #T_182a7_row3_col7, #T_182a7_row3_col8, #T_182a7_row3_col9, #T_182a7_row3_col10, #T_182a7_row3_col11, #T_182a7_row3_col12, #T_182a7_row3_col13, #T_182a7_row4_col3, #T_182a7_row4_col4, #T_182a7_row4_col5, #T_182a7_row4_col6, #T_182a7_row4_col7, #T_182a7_row4_col8, #T_182a7_row4_col9, #T_182a7_row4_col10, #T_182a7_row4_col11, #T_182a7_row4_col12, #T_182a7_row4_col13, #T_182a7_row5_col3, #T_182a7_row5_col4, #T_182a7_row5_col5, #T_182a7_row5_col6, #T_182a7_row5_col7, #T_182a7_row5_col8, #T_182a7_row5_col9, #T_182a7_row5_col10, #T_182a7_row5_col11, #T_182a7_row5_col12, #T_182a7_row5_col13, #T_182a7_row6_col3, #T_182a7_row6_col4, #T_182a7_row6_col5, #T_182a7_row6_col6, #T_182a7_row6_col7, #T_182a7_row6_col8, #T_182a7_row6_col9, #T_182a7_row6_col10, #T_182a7_row6_col11, #T_182a7_row6_col12, #T_182a7_row6_col13, #T_182a7_row7_col3, #T_182a7_row7_col4, #T_182a7_row7_col5, #T_182a7_row7_col6, #T_182a7_row7_col7, #T_182a7_row7_col8, #T_182a7_row7_col9, #T_182a7_row7_col10, #T_182a7_row7_col11, #T_182a7_row7_col12, #T_182a7_row7_col13, #T_182a7_row8_col3, #T_182a7_row8_col4, #T_182a7_row8_col5, #T_182a7_row8_col6, #T_182a7_row8_col7, #T_182a7_row8_col8, #T_182a7_row8_col9, #T_182a7_row8_col10, #T_182a7_row8_col11, #T_182a7_row8_col12, #T_182a7_row8_col13, #T_182a7_row9_col3, #T_182a7_row9_col4, #T_182a7_row9_col5, #T_182a7_row9_col6, #T_182a7_row9_col7, #T_182a7_row9_col8, #T_182a7_row9_col9, #T_182a7_row9_col10, #T_182a7_row9_col11, #T_182a7_row9_col12, #T_182a7_row9_col13, #T_182a7_row10_col3, #T_182a7_row10_col4, #T_182a7_row10_col5, #T_182a7_row10_col6, #T_182a7_row10_col7, #T_182a7_row10_col8, #T_182a7_row10_col9, #T_182a7_row10_col10, #T_182a7_row10_col11, #T_182a7_row10_col12, #T_182a7_row10_col13, #T_182a7_row11_col3, #T_182a7_row11_col4, #T_182a7_row11_col5, #T_182a7_row11_col6, #T_182a7_row11_col7, #T_182a7_row11_col8, #T_182a7_row11_col9, #T_182a7_row11_col10, #T_182a7_row11_col11, #T_182a7_row11_col12, #T_182a7_row11_col13, #T_182a7_row12_col3, #T_182a7_row12_col4, #T_182a7_row12_col5, #T_182a7_row12_col6, #T_182a7_row12_col7, #T_182a7_row12_col8, #T_182a7_row12_col9, #T_182a7_row12_col10, #T_182a7_row12_col11, #T_182a7_row12_col12, #T_182a7_row12_col13 {
#   color: red;
# }
# </style>
# <table id="T_182a7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pending Request Age</th>
#       <th id="T_182a7_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_182a7_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_182a7_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_182a7_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_182a7_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_182a7_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_182a7_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_182a7_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_182a7_level0_col8" class="col_heading level0 col8" >10</th>
#       <th id="T_182a7_level0_col9" class="col_heading level0 col9" >11</th>
#       <th id="T_182a7_level0_col10" class="col_heading level0 col10" >14</th>
#       <th id="T_182a7_level0_col11" class="col_heading level0 col11" >15</th>
#       <th id="T_182a7_level0_col12" class="col_heading level0 col12" >16</th>
#       <th id="T_182a7_level0_col13" class="col_heading level0 col13" >24</th>
#       <th id="T_182a7_level0_col14" class="col_heading level0 col14" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Infrastructure Teams</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_182a7_level0_row0" class="row_heading level0 row0" >Asset Management</th>
#       <td id="T_182a7_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_182a7_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_182a7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_182a7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_182a7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_182a7_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_182a7_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_182a7_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_182a7_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_182a7_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_182a7_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_182a7_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_182a7_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_182a7_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_182a7_row0_col14" class="data row0 col14" >6</td>
#     </tr>
#     <tr>
#       <th id="T_182a7_level0_row1" class="row_heading level0 row1" >Azure Support Management</th>
#       <td id="T_182a7_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_182a7_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_182a7_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_182a7_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_182a7_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_182a7_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_182a7_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_182a7_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_182a7_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_182a7_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_182a7_row1_col10" class="data row1 col10" >0</td>
